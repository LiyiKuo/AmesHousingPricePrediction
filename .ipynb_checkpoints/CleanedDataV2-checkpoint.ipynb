# %%
import pandas as pd
import numpy as np
import math
import re
import seaborn as sns
import matplotlib as plt
from matplotlib import pyplot as plt

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
train =pd.read_csv('data/train.csv', index_col=0)

# %%
train.drop(list(train[train['MasVnrArea'].isnull()].index), inplace=True)

# %%
train.iloc[[333, 531, 1265, 1359], :]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 335           60       RL         59.0     9042   Pave   NaN      IR1
# 534           20       RL         50.0     5000   Pave   NaN      Reg
# 1273          20       RL          NaN    13526   Pave   NaN      IR1
# 1368         160       RM         41.0     2665   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 335          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 534          Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1273         Lvl    AllPub   CulDSac  ...        0    NaN  MnPrv         NaN
# 1368         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 335        0      7    2008        WD         Normal     192000
# ...

# %%
train[train['LotConfig'] == "FR3"]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 334          120       RM         59.0     8198   Pave   NaN      Reg
# 532           70       RM         60.0     6155   Pave   NaN      IR1
# 1266         160       FV         35.0     3735   Pave   NaN      Reg
# 1360          20       RL        129.0    16737   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 334          Lvl    AllPub       FR3  ...        0    NaN   NaN         NaN
# 532          Lvl    AllPub       FR3  ...        0    NaN   NaN         NaN
# 1266         Lvl    AllPub       FR3  ...        0    NaN   NaN         NaN
# 1360         Lvl    AllPub       FR3  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 334        0      7    2008        WD         Normal     207000
# ...

# %%
train['LotFrontage'].plot(kind='hist')

# %%
g = sns.FacetGrid(train, col='LotConfig', margin_titles=True)
g.map(plt.hist, "LotFrontage")

# %%
train_frontage = train[~train['LotFrontage'].isnull()][['LotFrontage', 'LotArea', 'LotConfig']]
train_missing = train[train['LotFrontage'].isnull()][['LotFrontage', 'LotArea', 'LotConfig']]
imputed_df = pd.DataFrame(columns=['LotFrontage', 'LotArea', 'LotConfig'])

for config in train['LotConfig'].unique():
    complete_subset = train_frontage[train_frontage['LotConfig'] == config]
    missing_subset = train_missing[train_missing['LotConfig'] == config]
    k = int(np.sqrt(complete_subset.shape[0] + missing_subset.shape[0]))
    clf = KNeighborsRegressor(k, weights='distance')
    trained_model = clf.fit(complete_subset['LotArea'].values.reshape(-1, 1), 
                            complete_subset['LotFrontage'])
    if missing_subset['LotArea'].values.reshape(-1, 1).shape[0] > 0:
        imputed_values = trained_model.predict(missing_subset['LotArea'].values.reshape(-1, 1))
        missing_subset['LotFrontage'] = imputed_values.reshape(-1)
    imputed_df = pd.concat([imputed_df,complete_subset,missing_subset])
imputed_df = imputed_df.sort_index()
train['LotFrontage'] = imputed_df['LotFrontage']
# Out:
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
train.iloc[[333, 531, 1265, 1359], :]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 335           60       RL    59.000000     9042   Pave   NaN      IR1
# 534           20       RL    50.000000     5000   Pave   NaN      Reg
# 1273          20       RL    48.445432    13526   Pave   NaN      IR1
# 1368         160       RM    41.000000     2665   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 335          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 534          Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1273         Lvl    AllPub   CulDSac  ...        0    NaN  MnPrv         NaN
# 1368         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 335        0      7    2008        WD         Normal     192000
# ...

# %%
train['LotFrontage'].plot(kind='hist')

# %%
g = sns.FacetGrid(train, col='LotConfig', margin_titles=True)
g.map(plt.hist, "LotFrontage")

# %%
train[train['BsmtExposure'].isnull() & train['BsmtQual'].notnull()]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 949          60       RL         65.0    14006   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 949         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 949       0      2    2006        WD         Normal     192500
#
# [1 rows x 80 columns]

# %%
import random
random.seed(0)
#obs949 is randomly assigned a a non-"No" categery for BsmtExposure
train['BsmtExposure'][949]=train[train['BsmtExposure']!='No'].sample()['BsmtExposure']
# Out:
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#ob with a BsmtFinSF2 but shows "no basement" in the BsmtFinType2 col NEED TO IMPUTE  - random
train[train['BsmtFinType2'].isnull() & train['BsmtFinSF2']!=0]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 333          20       RL         85.0    10655   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 333         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333       0     10    2009        WD         Normal     284000
#
# [1 rows x 80 columns]

# %%
random.seed(0)
#obs333 is randomly assigned a non-"No" categery for BsmtFinType2
train['BsmtFinType2'][333]=train[train['BsmtFinType2']!='nan'].sample()['BsmtFinType2'].values[0]
# Out:
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#ob with Na in Electrical 
train[train['Electrical'].isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1380          80       RL         73.0     9735   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1380         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1380       0      5    2008        WD         Normal     167500
#
# [1 rows x 80 columns]

# %%
random.seed(0)
#obs1380 is randomly assigned a random
train['Electrical'][1380] = train['Electrical'].sample().values[0]
# Out:
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#for BsmtExposure - replace No with NoExposure; replace NaN with NoBsmt
train['BsmtExposure']=train['BsmtExposure'].str.replace('No','NoExposure')

# %%
train['BsmtExposure'].replace(np.NaN,'NoBsmt',inplace=True)

# %%
#GarageYrBlt - change No to numerical zero 
train['GarageYrBlt'].replace(np.NaN,0,inplace=True)

# %%
#cols for which NA will be replaced with "No" because NA is a true category thus need to change 
#to "No" so Pandas does not pick it up as np.NaN
#replacing fixing NA from only categorical Nominal
FixNA=['Alley', 'GarageType', 'MiscFeature']

# %%
#change np.NaN to "No"
for v in FixNA:
    train[v].replace(np.NaN,'No',inplace=True)

# %%
#spread MiscFeature, replace NaN with zero, and drop No. 
misc=train[['MiscFeature','MiscVal']]
misc=pd.pivot_table(misc,index='Id',columns='MiscFeature',values='MiscVal')
misc.replace(np.NaN,0,inplace=True)
misc=misc.drop(['No','Othr'],axis=1).apply(pd.to_numeric, errors='ignore', downcast='integer')

# %%
#combined misc with original DF and drop MiscFeature, MiscVal
train = pd.concat([train.drop(['MiscFeature','MiscVal'],axis=1),misc],axis=1)

# %%
#list of categorical variables 
cat_variables=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour','Utilities',
               'LotConfig', 'LandSlope','Neighborhood', 'Condition1', 'Condition2',
               'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl','Exterior1st', 
               'Exterior2nd', 'MasVnrType', 'Foundation','BsmtExposure','BsmtFinType2',
               'Heating','CentralAir','Electrical', 'GarageType','SaleType', 'SaleCondition']

# %%
for v in cat_variables:
    print(train[v].value_counts())
# Out:
# RL         1146
# RM          218
# FV           62
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# Pave    1446
# Grvl       6
# Name: Street, dtype: int64
# No      1362
# Grvl      50
# Pave      40
# Name: Alley, dtype: int64
# Reg    919
# IR1    482
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
# Lvl    1303
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
# AllPub    1451
# NoSeWa       1
# Name: Utilities, dtype: int64
# Inside     1046
# Corner      262
# CulDSac      93
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
# Gtl    1374
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
# NAmes      225
# CollgCr    149
# OldTown    113
# Edwards    100
# Somerst     83
# Gilbert     78
# NridgHt     76
# Sawyer      74
# NWAmes      73
# BrkSide     58
# SawyerW     58
# Crawfor     50
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# ...

# %%
feature_drop=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour','Utilities',
               'LandSlope','BldgType', 'HouseStyle','RoofStyle', 'RoofMatl',
              'BsmtFinType2','Heating','Electrical','Condition1', 'Condition2',
               'CentralAir','GarageType','SaleType','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
             '1stFlrSF','2ndFlrSF','LowQualFinSF']

#drop categorical features that present sparsity 
#MSZoning, Street, Alley, LotShape, LandCounter, Utilities, LandSlope, Condition 1,
#Condition 2, Roofstyle, RoofMatl, HouseStyle, #Heating #electrocial, SaleType, Neighborhood 
#centralair

#drop continuous variables that are redundant with total sqrt footage 
#BsmtFinSF2
#BsmtUnSF
#1stFlrSF
#2ndFlrSF
#LowQualFinSF
train=train.drop(feature_drop,axis=1)

# %%
train.loc[train['Neighborhood'] == 'SWISU','Neighborhood'] = 1
train.loc[train['Neighborhood'] == 'IDOTRR','Neighborhood'] = 2
train.loc[train['Neighborhood'] == 'OldTown','Neighborhood'] = 3
train.loc[train['Neighborhood'] == 'BrDale','Neighborhood'] = 4
train.loc[train['Neighborhood'] == 'Blueste','Neighborhood'] = 5
train.loc[train['Neighborhood'] == 'Edwards','Neighborhood'] = 6
train.loc[train['Neighborhood'] == 'MeadowV','Neighborhood'] = 7
train.loc[train['Neighborhood'] == 'BrkSide','Neighborhood'] = 8
train.loc[train['Neighborhood'] == 'NWAmes','Neighborhood'] = 9
train.loc[train['Neighborhood'] == 'NAmes','Neighborhood'] = 10
train.loc[train['Neighborhood'] == 'NPkVill','Neighborhood'] = 11
train.loc[train['Neighborhood'] == 'Sawyer','Neighborhood'] = 12
train.loc[train['Neighborhood'] == 'Gilbert','Neighborhood'] = 13
train.loc[train['Neighborhood'] == 'SawyerW','Neighborhood'] = 14
train.loc[train['Neighborhood'] == 'Crawfor','Neighborhood'] = 15
train.loc[train['Neighborhood'] == 'ClearCr','Neighborhood'] = 16
train.loc[train['Neighborhood'] == 'Mitchel','Neighborhood'] = 17
train.loc[train['Neighborhood'] == 'NoRidge','Neighborhood'] = 18
train.loc[train['Neighborhood'] == 'Blmngtn','Neighborhood'] = 19
train.loc[train['Neighborhood'] == 'CollgCr','Neighborhood'] = 20
train.loc[train['Neighborhood'] == 'Timber','Neighborhood'] = 21
train.loc[train['Neighborhood'] == 'Somerst','Neighborhood'] = 22
train.loc[train['Neighborhood'] == 'Veenker','Neighborhood'] = 23
train.loc[train['Neighborhood'] == 'NridgHt','Neighborhood'] = 24
train.loc[train['Neighborhood'] == 'StoneBr','Neighborhood'] = 25

# %%
#Exterior1st - Assign other to categories with count under 100 
train['Exterior1st'].replace(['CemntBd','BrkFace','WdShing','Stucco','AsbShng','Stone',
                                     'BrkComm','AsphShn','CBlock','ImStucc'],'Other',inplace=True)

# %%
#Exterior2nd - Assign other to categories with count under 100 train['Exterior2nd'].replace(['CemntBd','BrkFace','WdShing','Stucco','AsbShng','Stone',

train['Exterior2nd'].replace(['CemntBd','Wd Shng','Stucco','BrkFace','AsbShng','Stone',
                                     'Brk Cmn','AsphShn','CBlock','ImStucc'],'Other',inplace=True)

# %%
train['Foundation'].replace(['Slab','Stone','Wood'],'Other',inplace=True)

# %%
cat_variables2=['LotConfig','Exterior1st', 'Exterior2nd', 'Foundation','MasVnrType',
               'SaleCondition','BsmtExposure']

# %%
#dummify categorical nominal and binary variables
for v in cat_variables2:
    temp = pd.get_dummies(train[v],prefix=v, prefix_sep='_')
    temp = temp.drop(temp.iloc[:,0:1],axis=1)
    train = pd.concat([train.drop(v,axis=1),temp],axis=1)

# %%
train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60    65.000000     8450            7            5       2003
# 2             20    80.000000     9600            6            8       1976
# 3             60    68.000000    11250            7            5       2001
# 4             70    60.000000     9550            7            5       1915
# 5             60    84.000000    14260            8            5       2000
# 6             50    85.000000    14115            5            5       1993
# 7             20    75.000000    10084            8            5       2004
# 8             60    86.887741    10382            7            6       1973
# 9             50    51.000000     6120            7            5       1931
# 10           190    50.000000     7420            5            6       1939
# 11            20    70.000000    11200            5            5       1965
# ...

# %%
# #list for Condition1 and Condition2
# Condition1 = list(train.filter(regex='Condition1').columns)
# Condition1.remove('Condition1_RRNe')
# Condition2 = list(train.filter(regex='Condition2').columns)

# %%
# #combine all Condition1 and Condition2 columns and drop Condition2
# for i,j in zip(Condition1,Condition2):
#     train[i] = train[i] | train[j]
#     train.drop(j,axis=1,inplace=True)
# train

# %%
LST = ('ExterQual','ExterCond','HeatingQC','KitchenQual')
LST1 = ('BsmtQual','BsmtCond','FireplaceQu','GarageQual','GarageCond')
LST2 = ('BsmtFinType1')
LST3 = ('Functional')
LST4 = ('GarageFinish')
LST5 = ('PavedDrive')
LST6 = ('PoolQC')
LST7 = ('Fence')

# %%
train['TotalBath']=train['BsmtFullBath']+train['BsmtHalfBath']+train['FullBath']+train['HalfBath']
train['Bedroom/Bathroom']=train['BedroomAbvGr']/train['TotalBath']
train['Bedroom/Bathroom'].unique()
# Out:
# array([0.75      , 1.        , 1.5       , 0.33333333, 0.66666667,
#        2.        , 3.        , 1.33333333, 0.        , 1.25      ,
#        0.5       , 1.66666667, 4.        , 5.        , 0.25      ,
#        2.5       , 0.6       , 0.8       ])

# %%
for x in LST:
    train.loc[train[x] == 'Po',x] = 1
    train.loc[train[x] == 'Fa',x] = 2
    train.loc[train[x] == 'TA',x] = 3
    train.loc[train[x] == 'Gd',x] = 4
    train.loc[train[x] == 'Ex',x] = 5

# %%
for x in LST1:
    train[x].fillna(0, inplace=True)    
    train.loc[train[x] == 'Po',x] = 1
    train.loc[train[x] == 'Fa',x] = 2
    train.loc[train[x] == 'TA',x] = 3
    train.loc[train[x] == 'Gd',x] = 4
    train.loc[train[x] == 'Ex',x] = 5
# Out:
# /Users/zhuwang/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# Nan values mean there are none for this there is no basement therefore value is 0
# all columns for ordinal has no basement or features if filled with 0
x = LST2
train[x].fillna(0, inplace=True)
train.loc[train[x] == 'Unf',x] = 1
train.loc[train[x] == 'LwQ',x] = 2
train.loc[train[x] == 'Rec',x] = 3
train.loc[train[x] == 'BLQ',x] = 4
train.loc[train[x] == 'ALQ',x] = 5
train.loc[train[x] == 'GLQ',x] = 6

# %%
x = LST3
train.loc[train[x] == 'Sal',x] = 1
train.loc[train[x] == 'Sev',x] = 2
train.loc[train[x] == 'Maj2',x] = 3
train.loc[train[x] == 'Maj1',x] = 4
train.loc[train[x] == 'Mod',x] = 5
train.loc[train[x] == 'Min2',x] = 6
train.loc[train[x] == 'Min1',x] = 6
train.loc[train[x] == 'Typ',x] = 6

# %%
x = LST4
train[x].fillna(0, inplace=True)
train.loc[train[x] == 'Unf',x] = 1
train.loc[train[x] == 'RFn',x] = 2
train.loc[train[x] == 'Fin',x] = 3

# %%
x = LST5
train.loc[train[x] == 'N',x] = 1
train.loc[train[x] == 'P',x] = 2
train.loc[train[x] == 'Y',x] = 3

# %%
x = LST6
train[x].fillna(0, inplace=True)
train.loc[train[x] == 'Fa',x] = 1
train.loc[train[x] == 'TA',x] = 2
train.loc[train[x] == 'Gd',x] = 3
train.loc[train[x] == 'Ex',x] = 4

# %%
x = LST7
train[x].fillna(0, inplace=True)
train.loc[train[x] == 'MnWw',x] = 1
train.loc[train[x] == 'GdWo',x] = 2
train.loc[train[x] == 'MnPrv',x] = 3
train.loc[train[x] == 'GdPrv',x] = 4

# %%
# These are the ordinal columns of the training data set
# train[['OverallQual','OverallCond','ExterQual','ExterCond','BsmtQual','BsmtCond','BsmtFinType1','HeatingQC','BsmtFullBath','KitchenQual',
#       'Functional',
# 'FireplaceQu','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','SalePrice']]
#dropping bathroom columns since we made a new column Total Bathroom
train = train.drop('BsmtFullBath',1)
train = train.drop('BsmtHalfBath',1)
train = train.drop('FullBath',1)
train = train.drop('HalfBath',1)

# %%
train[train.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
train = train.drop('MSSubClass', 1)
train
# Out:
#       LotFrontage  LotArea  Neighborhood  OverallQual  OverallCond  YearBuilt  \
# Id
# 1       65.000000     8450            20            7            5       2003
# 2       80.000000     9600            23            6            8       1976
# 3       68.000000    11250            20            7            5       2001
# 4       60.000000     9550            15            7            5       1915
# 5       84.000000    14260            18            8            5       2000
# 6       85.000000    14115            17            5            5       1993
# 7       75.000000    10084            22            8            5       2004
# 8       86.887741    10382             9            7            6       1973
# 9       51.000000     6120             3            7            5       1931
# 10      50.000000     7420             8            5            6       1939
# 11      70.000000    11200            12            5            5       1965
# ...

# %%
train.to_csv('data/train_cleanV2.csv')

# %%
# Recursive Feature Elimination
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV


X = train.drop('SalePrice', axis=1)
target = train[['SalePrice']]

# rfecv = RFECV(estimator=rfc, step=1, cv=5, scoring='accuracy')
# rfecv = rfecv.fit(X, target)

# %%
# rfecv.grid_scores_

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import RFECV
from sklearn import datasets, linear_model
import warnings
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
ols = linear_model.LinearRegression()
clf_lr = LogisticRegression()

# %%
# X= train[['LotFrontage','LotArea',
# 'YearBuilt',
# 'YearRemodAdd',
# 'MasVnrArea',
# 'BsmtFinSF1',
# 'BsmtFinSF2',
# 'BsmtUnfSF',
# 'TotalBsmtSF',
# '1stFlrSF',
# '2ndFlrSF',
# 'LowQualFinSF',
# 'GrLivArea',
# 'BedroomAbvGr',
# 'KitchenAbvGr',
# 'TotRmsAbvGrd',
# 'Fireplaces',
# 'GarageYrBlt',
# 'GarageCars',
# 'GarageCars',
# 'WoodDeckSF',
# 'OpenPorchSF',
# 'EnclosedPorch',
# '3SsnPorch',
# 'ScreenPorch',
# 'PoolArea',
# 'MoSold',
# 'YrSold']]

# %%
rfecv = RFECV(estimator=ols, step=1, cv=5, scoring='neg_mean_squared_error')
X = train('SalePrice', axis=1)
y = train[['SalePrice']]
# Fit recursive feature eliminator 
rfecv.fit(X, y)

# Recursive feature elimination
rfecv.transform(X)
