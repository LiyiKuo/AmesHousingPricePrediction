# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv', index_col=0)

# %%
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %%
train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
train['LotFrontage'].plot(kind='hist')

# %%
g = sns.FacetGrid(train, col='LotConfig', margin_titles=True)
g.map(plt.hist, "LotFrontage")

# %%
train[train['LotFrontage'].isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 15           Lvl    AllPub    Corner  ...        0    NaN   GdWo         NaN
# 17           Lvl    AllPub   CulDSac  ...        0    NaN    NaN        Shed
# 25           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 32           Lvl    AllPub   CulDSac  ...        0    NaN  MnPrv         NaN
# 43           Lvl    AllPub   CulDSac  ...        0    NaN  MnPrv         NaN
# 44           Lvl    AllPub   CulDSac  ...        0    NaN  MnPrv         NaN
# 51           Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 65           Lvl    AllPub    Inside  ...        0    NaN  GdPrv         NaN
# 67           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 77           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 85           Lvl    AllPub    Inside  ...        0    NaN    NaN        Shed
# 96           Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 101          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 105          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 112          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 114          Bnk    AllPub    Corner  ...        0    NaN  MnPrv         NaN
# 117          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 121          Low    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 127          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 132          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 134          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 137          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 148          Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 150          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 153          Lvl    AllPub   CulDSac  ...        0    NaN   GdWo         NaN
# 154          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 161          Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 167          Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1301         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 1302         Bnk    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1310         Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# 1313         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1319         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 1322         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 1343         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1347         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 1349         Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1355         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1357         Lvl    AllPub    Corner  ...        0    NaN   GdWo         NaN
# 1358         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 1359         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1363         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1366         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1369         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1374         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1382         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 1384         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1397         Bnk    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1408         Lvl    AllPub    Corner  ...        0    NaN  MnPrv         NaN
# 1418         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1420         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1424         Lvl    AllPub   CulDSac  ...      738     Gd  GdPrv         NaN
# 1425         Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# 1430         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 1432         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1442         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1444         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1447         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 8        350     11    2009        WD         Normal     200000
# 13         0      9    2008        WD         Normal     144000
# 15         0      5    2008        WD         Normal     157000
# 17       700      3    2010        WD         Normal     149000
# 25         0      5    2010        WD         Normal     154000
# 32         0      6    2008        WD         Normal     149350
# 43         0     12    2007        WD         Normal     144000
# 44         0      7    2008        WD         Normal     130250
# 51         0      7    2007        WD         Normal     177000
# 65         0      2    2009        WD         Normal     219500
# 67         0      7    2010        WD         Normal     180000
# 77         0      4    2008        WD         Normal     135750
# 85       700      5    2009        WD         Normal     168500
# 96       480      4    2009        WD         Normal     185000
# 101        0      2    2010        WD         Normal     205000
# 105        0      6    2007        WD         Normal     169500
# 112        0      4    2010        WD         Normal     180000
# 114        0     10    2007       COD        Abnorml     217000
# 117        0      9    2009        WD         Normal     139000
# 121        0     10    2006        WD         Normal     180000
# 127        0      2    2007        WD         Normal     128000
# 132        0      7    2009        WD         Normal     244000
# 134        0      6    2009        WD         Normal     220000
# 137        0      7    2007        WD         Normal     143000
# 148        0      5    2010        WD         Normal     222500
# 150        0      4    2006        WD         Normal     115000
# 153        0      6    2006        WD         Normal     190000
# 154        0      3    2008        WD         Normal     235000
# 161        0      6    2008        WD         Normal     162500
# 167        0     11    2009       COD         Normal     190000
# ...      ...    ...     ...       ...            ...        ...
# 1301       0      5    2009        WD         Normal     225000
# 1302       0     11    2009        WD         Normal     177500
# 1310       0      6    2008        WD         Normal     179200
# 1313       0      6    2007        WD         Normal     302000
# 1319       0      8    2006        WD         Normal     275000
# 1322       0      7    2008        WD         Normal      72500
# 1343       0      8    2007        WD         Normal     228500
# 1347       0      6    2006        WD         Normal     262500
# 1349       0      8    2007        WD         Normal     215000
# 1355       0      6    2008        WD         Normal     235000
# 1357       0     10    2008        WD         Normal     110000
# 1358       0      4    2010        WD         Normal     149900
# 1359       0      6    2010        WD         Normal     177500
# 1363       0      6    2009        WD         Normal     104900
# 1366       0      1    2010        WD         Normal     216000
# 1369       0      6    2009        WD         Normal     144000
# 1374       0      3    2007        WD         Normal     466500
# 1382       0      5    2008        WD         Normal     237500
# 1384       0      8    2007        WD         Normal     112000
# 1397       0      6    2010        WD         Normal     160000
# 1408       0      3    2009        WD         Normal     112000
# 1418       0      5    2009        WD         Normal     340000
# 1420       0     12    2006        WD         Normal     223000
# 1424       0      8    2006        WD         Alloca     274970
# 1425       0      6    2007        WD         Normal     144000
# 1430       0      4    2007        WD         Normal     182900
# 1432       0     10    2009        WD         Normal     143750
# 1442       0      5    2008        WD         Normal     149300
# 1444       0      5    2009        WD         Normal     121000
# 1447       0      4    2010        WD         Normal     157900
#
# [259 rows x 80 columns]

# %%
train['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
train_frontage = train[~train['LotFrontage'].isnull()][['LotFrontage', 'LotArea', 'LotConfig']]
train_missing = train[train['LotFrontage'].isnull()][['LotFrontage', 'LotArea', 'LotConfig']]
imputed_df = pd.DataFrame(columns=['LotFrontage', 'LotArea', 'LotConfig'])

for config in train['LotConfig'].unique()[:-1]:
    complete_subset = train_frontage[train_frontage['LotConfig'] == config]
    missing_subset = train_missing[train_missing['LotConfig'] == config]
    k = int(np.sqrt(complete_subset.shape[0] + missing_subset.shape[0]))
    clf = KNeighborsRegressor(k, weights='distance')
    trained_model = clf.fit(complete_subset['LotArea'].values.reshape(-1, 1), 
                            complete_subset['LotFrontage'])
    if missing_subset['LotArea'].values.reshape(-1, 1).shape[0] > 1:
        imputed_values = trained_model.predict(missing_subset['LotArea'].values.reshape(-1, 1))
        
    missing_subset['LotFrontage'] = imputed_values.reshape(-1)
    imputed_df = pd.concat([imputed_df,complete_subset,missing_subset])
imputed_df = imputed_df.sort_index()
imputed_df
# Out:
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       LotFrontage LotArea LotConfig
# 1       65.000000    8450    Inside
# 2       80.000000    9600       FR2
# 3       68.000000   11250    Inside
# 4       60.000000    9550    Corner
# 5       84.000000   14260       FR2
# 6       85.000000   14115    Inside
# 7       75.000000   10084    Inside
# 8       86.887741   10382    Corner
# 9       51.000000    6120    Inside
# 10      50.000000    7420    Corner
# 11      70.000000   11200    Inside
# 12      85.000000   11924    Inside
# 13      80.188358   12968    Inside
# 14      91.000000   10652    Inside
# 15      91.577741   10920    Corner
# 16      51.000000    6120    Corner
# 17      58.889071   11241   CulDSac
# 18      72.000000   10791    Inside
# 19      66.000000   13695    Inside
# 20      70.000000    7560    Inside
# 21     101.000000   14215    Corner
# 22      57.000000    7449    Inside
# 23      75.000000    9742    Inside
# 24      44.000000    4224    Inside
# 25      55.337693    8246    Inside
# 26     110.000000   14230    Corner
# 27      60.000000    7200    Corner
# 28      98.000000   11478    Inside
# 29      47.000000   16321   CulDSac
# 30      60.000000    6324    Inside
# ...           ...     ...       ...
# 1431    60.000000   21930    Inside
# 1432    41.902069    4928    Inside
# 1433    60.000000   10800    Inside
# 1434    93.000000   10261    Inside
# 1435    80.000000   17400    Inside
# 1436    80.000000    8400    Inside
# 1437    60.000000    9000       FR2
# 1438    96.000000   12444       FR2
# 1439    90.000000    7407    Inside
# 1440    80.000000   11584    Inside
# 1441    79.000000   11526    Inside
# 1442    39.452923    4426    Inside
# 1443    85.000000   11003    Inside
# 1444    67.941151    8854    Inside
# 1445    63.000000    8500       FR2
# 1446    70.000000    8400    Inside
# 1447    85.309739   26142   CulDSac
# 1448    80.000000   10000    Inside
# 1449    70.000000   11767    Inside
# 1450    21.000000    1533    Inside
# 1451    60.000000    9000       FR2
# 1452    78.000000    9262    Inside
# 1453    35.000000    3675    Inside
# 1454    90.000000   17217    Inside
# 1455    62.000000    7500    Inside
# 1456    62.000000    7917    Inside
# 1457    85.000000   13175    Inside
# 1458    66.000000    9042    Inside
# 1459    68.000000    9717    Inside
# 1460    75.000000    9937    Inside
#
# [1456 rows x 3 columns]

# %%
train['LotConfig'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bcc4eb5e677d> in <module>
# ----> 1 train['LotConfig'].unique()
#
# NameError: name 'train' is not defined

# %%
train.shape

# %%
train['LotArea'].values

# %%
imputed_df = pd.DataFrame(columns=['LotFrontage', 'LotArea', 'LotConfig'])
train_frontage = train[~train['LotFrontage'].isnull()][['LotFrontage', 'LotArea', 'LotConfig']]
imputed_df = imputed_df.append(train_frontage[train_frontage['LotConfig'] == 'Corner'])
imputed_df = imputed_df.append(train_frontage[train_frontage['LotConfig'] == 'Inside'])
imputed_df.sort_index()

# %%
for x in LIST:
    values = train[x].unique()
train['ExterCond'] = train['ExterCond'].apply(lambda x: np.where(values == x)[0][0] + 1)
train['ExterCond']

# %%
values = train['ExterCond'].unique()
np.where(values == 'Fa')[0][0]
